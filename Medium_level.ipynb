# %%
! pip install pandas seaborn matplotlib

# %%
import pandas  as pd
import seaborn as  sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Preprocessing

# %%
data = pd.read_csv("Stars_Names.csv")

# %%
data['Approval Date'] = pd.to_datetime(data['Approval Date'])
data['Approval Month'] = data['Approval Date'].dt.month
data['Approval Year'] = data['Approval Date'].dt.year

# %% [markdown]
# ## Questions

# %% [markdown]
# ### 1. *Heatmap of Approvals by Year and Month*

# %%
heatmap_data = data.groupby(['Approval Year', 'Approval Month']).size().unstack(fill_value=0)

# Plotting Graph
plt.figure(figsize=(6, 4))
sns.heatmap(heatmap_data, cmap='YlOrRd', linewidths=0) 
plt.title('Approval Frequency by Month and Year', fontsize=14)
plt.ylabel('Approval Year', fontsize=12)
plt.xlabel('Approval Month', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1. *Boxplot - Month vs Year*

# %%
daily_counts = data.groupby(data['Approval Date'].dt.date).size().reset_index(name='Count')
daily_counts['Approval Date'] = pd.to_datetime(daily_counts['Approval Date'])
daily_counts['Month'] = daily_counts['Approval Date'].dt.month
daily_counts['Year'] = daily_counts['Approval Date'].dt.year

plt.figure(figsize=(6, 4))
sns.boxplot(x='Month', y='Count', data=daily_counts)
plt.title('Distribution of Approvals by Month')
plt.xlabel('Month')
plt.ylabel('Number of Approvals')
plt.show()

# %% [markdown]
# ### 3. *Scatter Plot - Year vs Month*

# %%
plt.figure(figsize=(6, 4))
sns.scatterplot(x='Approval Year', y='Approval Month', data=data, alpha=0.6)

plt.title('Scatter Plot of Approvals by Year and Month')
plt.xlabel('Year')
plt.ylabel('Month')
plt.yticks(ticks=range(1, 13), labels=[
    'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
    'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'
])
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
